# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplleaflet
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.font_manager as fm
# %matplotlib inline
df = pd.read_csv('Energy_Dataset.csv')
df.Timestamp = pd.to_datetime(df.Timestamp)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928560 entries, 0 to 928559
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Customer                 928560 non-null  int64
#  1   Postcode                 928560 non-null  int64
#  2   Timestamp                928560 non-null  datetime64[ns]
#  3   Solar_Production_kWh     928560 non-null  float64
#  4   Energy_Consumption_kWh   928560 non-null  float64
#  5   Heating_Consumption_kWh  382608 non-null  float64
#  6   Price_AUD/MWh            928507 non-null  float64
#  7   Total_Demand_MWh         928507 non-null  float64
#  8   Latitude                 928560 non-null  float64
#  9   Longitude                928560 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(2)
# memory usage: 70.8 MB

# %%
locs =(df.Latitude.astype('str') + '+' + df.Longitude.astype('str')).unique().tolist()
lat=[]
long=[]
for loc in locs:
    a = loc.split("+")
    lat.append(float(a[0]))
    long.append(float(a[1]))
plt.figure(figsize=(2,10))
#mplleaflet.display()
plt.scatter(long, lat, marker='*', c='b', alpha=0.7, s=100)

mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="600"></iframe>
